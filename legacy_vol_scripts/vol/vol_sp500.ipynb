# %%
import sys, os
from datetime import datetime, timedelta
import pandas as pd

project_root = os.path.abspath("..")
sys.path.insert(0, project_root)

data_dir = os.path.join(project_root, "data")
os.makedirs(data_dir, exist_ok=True)

# %%
from import_other_options import import_sp500_options_data

start_date = datetime.now().date()
end_date = (datetime.now() + timedelta(days=800)).date()

spx_df = import_sp500_options_data(
    start_date=start_date,
    end_date=end_date,
    ticker="^SPX",
    output_dir=data_dir,
    filter_by_date=False

)

print("✓ spx_df loaded:", len(spx_df))
spx_df.head()
# Out:
# ⚠️  Warning: Data directory path doesn't contain 'Option_Pricing': /Users/mathisvillaret/Documents (mac)/Le CODE/data
#    Expected path should contain: .../Option_Pricing/data/
#    Current working directory: /Users/mathisvillaret/Documents (mac)/Le CODE/Option_Pricing
#    ✅ Fixed path to: /Users/mathisvillaret/Documents (mac)/Le CODE/data
# 📁 Data will be saved to / loaded from: /Users/mathisvillaret/Documents (mac)/Le CODE/data
# 📂 Existing CSV found, loading instead of fetching from Yahoo Finance:
#    /Users/mathisvillaret/Documents (mac)/Le CODE/data/sp500_options_SPX_20251216_004012.csv
# 📊 Total rows in CSV: 16401
# ✅ Loaded all 16401 options from CSV (no date filtering)
# ✓ spx_df loaded: 16401
#    expiry_str expiry_date  strike type   mark_iv  mark_price  \
# 0  2025-12-16  2025-12-16  2800.0    P  3.234377        0.05
# 1  2025-12-16  2025-12-16  3000.0    P  2.984378        0.05
# 2  2025-12-16  2025-12-16  3200.0    P  2.765628        0.25
# 3  2025-12-16  2025-12-16  3400.0    P  2.546879        0.05
# 4  2025-12-16  2025-12-16  3600.0    P  2.343754        0.05
#
#    underlying_price  open_interest  bid_price  ask_price  best_bid_price  \
# 0       6816.509766          102.0        0.0       0.05             0.0
# 1       6816.509766           10.0        0.0       0.05             0.0
# 2       6816.509766            2.0        0.0       0.05             0.0
# 3       6816.509766          201.0        0.0       0.05             0.0
# 4       6816.509766           17.0        0.0       0.05             0.0
#
#    best_ask_price  volume           instrument_name       contractSymbol  \
# 0            0.05     1.0  ^SPX-2025-12-16-2800.0-P  SPXW251216P02800000
# 1            0.05     1.0  ^SPX-2025-12-16-3000.0-P  SPXW251216P03000000
# 2            0.05     1.0  ^SPX-2025-12-16-3200.0-P  SPXW251216P03200000
# 3            0.05    50.0  ^SPX-2025-12-16-3400.0-P  SPXW251216P03400000
# 4            0.05    10.0  ^SPX-2025-12-16-3600.0-P  SPXW251216P03600000
#
#   underlying_ticker
# 0              ^SPX
# 1              ^SPX
# 2              ^SPX
# 3              ^SPX
# 4              ^SPX

# %%
# Cell 2 - Utilisez la date du CSV au lieu de datetime.now()
from datetime import datetime
as_of = datetime(2025, 12, 12)  # Date de création du CSV (12 décembre 2025)
spx_df["expiry_date"] = pd.to_datetime(spx_df["expiry_date"])
spx_df["T"] = (spx_df["expiry_date"] - pd.Timestamp(as_of)).dt.total_seconds() / (365.25 * 24 * 3600)

print(f"Options avec T > 1 an dans les données brutes: {len(spx_df[spx_df['T'] > 1.0])}")
print(f"T max dans les données: {spx_df['T'].max():.4f} ans")
# Out:
# Options avec T > 1 an dans les données brutes: 1001
# T max dans les données: 1.5113 ans

# %%
from iv_surface_spx import SPXIVSurface, SurfaceConfig

as_of_date = datetime.now()

cfg = SurfaceConfig(
    r=0.05,
    min_bid=0.01,
    max_rel_spread=0.25,
    min_oi=10,
    min_volume=1,
    grid_n=60,
    rbf_smoothing=0.5,
    min_T=1/365,  # Commencer à ~1 jour
    max_T=2.0,     # Aller jusqu'à 2 ans
    as_of=as_of_date
)

spx_surface = SPXIVSurface(spx_df, cfg)
print("Rows after cleaning:", len(spx_surface.df))
spx_surface.df.head()
# Out:
# Rows after cleaning: 6263
#    expiry_str expiry_date  strike type   mark_iv  mark_price  \
# 0  2026-01-05  2026-01-05  5500.0    P  0.371588        1.70
# 1  2026-01-05  2026-01-05  5600.0    P  0.350837        1.80
# 2  2026-01-05  2026-01-05  5700.0    P  0.328864        2.15
# 3  2026-01-05  2026-01-05  5800.0    P  0.307472        2.50
# 4  2026-01-05  2026-01-05  5875.0    P  0.291236        2.80
#
#    underlying_price  open_interest  bid_price  ask_price  ...  \
# 0       6816.509766            381       1.45       1.75  ...
# 1       6816.509766            183       1.70       2.05  ...
# 2       6816.509766            197       2.00       2.35  ...
# 3       6816.509766             29       2.35       2.75  ...
# 4       6816.509766              2       2.70       3.10  ...
#
#    underlying_ticker         T            S   bid   ask    mid  rel_spread  \
# 0               ^SPX  0.006702  6816.509766  1.45  1.75  1.600    0.187500
# 1               ^SPX  0.006702  6816.509766  1.70  2.05  1.875    0.186667
# 2               ^SPX  0.006702  6816.509766  2.00  2.35  2.175    0.160920
# 3               ^SPX  0.006702  6816.509766  2.35  2.75  2.550    0.156863
# 4               ^SPX  0.006702  6816.509766  2.70  3.10  2.900    0.137931
#
#       iv_pct            F         x
# 0  37.158832  6837.158261 -0.217624
# 1  35.083657  6837.158261 -0.199606
# 2  32.886413  6837.158261 -0.181906
# 3  30.747152  6837.158261 -0.164514
# 4  29.123634  6837.158261 -0.151666
#
# [5 rows x 25 columns]

# %%
fig = spx_surface.plot(
    title="SPX Implied Volatility Surface (OTM, forward-moneyness)",
    interpolate=True
)
fig.show()

# %% [markdown]
# ### Summary (SPX IV Surface — OTM, forward-moneyness)
#
# - The surface exhibits a **strong downside skew**: implied volatility increases sharply as
#   **log-moneyness** $\ln(K/F)$ becomes more negative (deep OTM puts).
#   This is typical for SPX and reflects **crash-risk insurance demand**.
#
# - Volatility varies with **time to expiry**, and the **term structure depends on moneyness**
#   (the maturity effect is not uniform across strikes).
#
# - The “striped” pattern in the white points is expected because option quotes exist on
#   **discrete expiries and strikes**; the smooth surface is an interpolation across that grid.
#
# - Extremely high IV levels (e.g., **60–70%**) in the far left tail are likely driven by
#   **illiquid/unstable quotes and interpolation extrapolation**, so the outer tail should be
#   treated cautiously (e.g., **outlier filtering** or **restricting the moneyness range** before fitting).

# %%
from import_other_options import import_sp500_options_data

start_date = datetime.now().date()
end_date = (datetime.now() + timedelta(days=360)).date()

spx_df1 = import_sp500_options_data(
    start_date=start_date,
    end_date=end_date,
    ticker="^SPX",
    output_dir=data_dir
)

print("✓ spx_df loaded:", len(spx_df1))
spx_df
# Out:
# ⚠️  Warning: Data directory path doesn't contain 'Option_Pricing': /Users/mathisvillaret/Documents (mac)/Le CODE/data
#    Expected path should contain: .../Option_Pricing/data/
#    Current working directory: /Users/mathisvillaret/Documents (mac)/Le CODE/Option_Pricing
#    ✅ Fixed path to: /Users/mathisvillaret/Documents (mac)/Le CODE/data
# 📁 Data will be saved to / loaded from: /Users/mathisvillaret/Documents (mac)/Le CODE/data
# 📂 Existing CSV found, loading instead of fetching from Yahoo Finance:
#    /Users/mathisvillaret/Documents (mac)/Le CODE/data/sp500_options_SPX_20251216_004012.csv
# 📊 Total rows in CSV: 16401
# ✅ Loaded 11043 options after filtering by date range (2026-01-02 to 2026-12-28)
#    (5358 options filtered out)
# ✓ spx_df loaded: 11043
#        expiry_str expiry_date   strike type   mark_iv  mark_price  \
# 0      2025-12-16  2025-12-16   2800.0    P  3.234377        0.05
# 1      2025-12-16  2025-12-16   3000.0    P  2.984378        0.05
# 2      2025-12-16  2025-12-16   3200.0    P  2.765628        0.25
# 3      2025-12-16  2025-12-16   3400.0    P  2.546879        0.05
# 4      2025-12-16  2025-12-16   3600.0    P  2.343754        0.05
# ...           ...         ...      ...  ...       ...         ...
# 16396  2027-06-17  2027-06-17  10400.0    C  0.155351        8.60
# 16397  2027-06-17  2027-06-17  10800.0    C  0.160279        5.20
# 16398  2027-06-17  2027-06-17  11000.0    C  0.162904        2.90
# 16399  2027-06-17  2027-06-17  11200.0    C  0.165902        2.20
# 16400  2027-06-17  2027-06-17  11400.0    C  0.168992        2.00
#
#        underlying_price  open_interest  bid_price  ask_price  best_bid_price  \
# 0           6816.509766          102.0       0.00       0.05            0.00
# 1           6816.509766           10.0       0.00       0.05            0.00
# 2           6816.509766            2.0       0.00       0.05            0.00
# 3           6816.509766          201.0       0.00       0.05            0.00
# 4           6816.509766           17.0       0.00       0.05            0.00
# ...                 ...            ...        ...        ...             ...
# 16396       6816.509766          186.0       2.65       7.50            2.65
# 16397       6816.509766           21.0       0.65       5.50            0.65
# 16398       6816.509766           20.0       0.05       4.80            0.05
# 16399       6816.509766           11.0       0.05       4.30            0.05
# 16400       6816.509766           54.0       0.05       3.90            0.05
#
#        best_ask_price  volume            instrument_name       contractSymbol  \
# 0                0.05     1.0   ^SPX-2025-12-16-2800.0-P  SPXW251216P02800000
# 1                0.05     1.0   ^SPX-2025-12-16-3000.0-P  SPXW251216P03000000
# 2                0.05     1.0   ^SPX-2025-12-16-3200.0-P  SPXW251216P03200000
# 3                0.05    50.0   ^SPX-2025-12-16-3400.0-P  SPXW251216P03400000
# 4                0.05    10.0   ^SPX-2025-12-16-3600.0-P  SPXW251216P03600000
# ...               ...     ...                        ...                  ...
# 16396            7.50     1.0  ^SPX-2027-06-17-10400.0-C   SPX270617C10400000
# 16397            5.50    10.0  ^SPX-2027-06-17-10800.0-C   SPX270617C10800000
# 16398            4.80    20.0  ^SPX-2027-06-17-11000.0-C   SPX270617C11000000
# 16399            4.30     1.0  ^SPX-2027-06-17-11200.0-C   SPX270617C11200000
# 16400            3.90     1.0  ^SPX-2027-06-17-11400.0-C   SPX270617C11400000
#
#       underlying_ticker         T
# 0                  ^SPX  0.010951
# 1                  ^SPX  0.010951
# 2                  ^SPX  0.010951
# 3                  ^SPX  0.010951
# 4                  ^SPX  0.010951
# ...                 ...       ...
# 16396              ^SPX  1.511294
# 16397              ^SPX  1.511294
# 16398              ^SPX  1.511294
# 16399              ^SPX  1.511294
# 16400              ^SPX  1.511294
#
# [16401 rows x 17 columns]

# %%
cfg = SurfaceConfig(
    min_T=1/365,  # Min 3-4 days Base 1 year =1, 1 month =1/12 etc.
    max_T=365   #
)
spx_surface_test = SPXIVSurface(spx_df1, cfg)
surface = SPXIVSurface(spx_df, cfg=cfg)

fig = spx_surface_test.plot(
    title="SPX Implied Volatility Surface (OTM, forward-moneyness)",
    interpolate=True
)
fig.show()

# %%
print(f"Options bf filtering : {len(spx_df1)}")
surface = SPXIVSurface(spx_df1, cfg=cfg)
print(f"Options after filtering: {len(surface.df)}")
# Out:
# Options bf filtering : 11043
# Options after filtering: 5921

# %%
from datetime import datetime
import pandas as pd

# Convert expiry dates to datetime
spx_df['expiry_date'] = pd.to_datetime(spx_df['expiry_date'])

# Set reference date (as of today)
as_of = datetime.now()

# Calculate time to expiration in years
spx_df['T'] = (spx_df['expiry_date'] - pd.Timestamp(as_of)).dt.total_seconds() / (365.25 * 24 * 3600)

# Display the time range in your data
print(f"T min in your data: {spx_df['T'].min():.3f}")
print(f"T max in your data: {spx_df['T'].max():.3f}")
# Out:
# T min in your data: -0.048
# T max in your data: 1.452

# %%
# Test avec un intervalle plus court
start_date = datetime.now().date()
end_date = (datetime.now() + timedelta(days=1000)).date() 

spx_df2 = import_sp500_options_data(
    start_date=start_date,
    end_date=end_date,
    ticker="^SPX",
    output_dir=data_dir
)
print(f"Options avec intervalle de 30 jours: {len(spx_df2)}")
# Devrait être moins que 14694
# Out:
# ⚠️  Warning: Data directory path doesn't contain 'Option_Pricing': /Users/mathisvillaret/Documents (mac)/Le CODE/data
#    Expected path should contain: .../Option_Pricing/data/
#    Current working directory: /Users/mathisvillaret/Documents (mac)/Le CODE/Option_Pricing
#    ✅ Fixed path to: /Users/mathisvillaret/Documents (mac)/Le CODE/data
# 📁 Data will be saved to / loaded from: /Users/mathisvillaret/Documents (mac)/Le CODE/data
# 📂 Existing CSV found, loading instead of fetching from Yahoo Finance:
#    /Users/mathisvillaret/Documents (mac)/Le CODE/data/sp500_options_SPX_20251216_004012.csv
# 📊 Total rows in CSV: 16401
# ✅ Loaded 11651 options after filtering by date range (2026-01-02 to 2028-09-28)
#    (4750 options filtered out)
# Options avec intervalle de 30 jours: 11651

# %%
spx_df2 = import_sp500_options_data(
    start_date=start_date,
    end_date=end_date,
    ticker="^SPX",
    output_dir=data_dir,
    filter_by_date=False  # ⬅️ Désactive le filtrage par date
)
# Out:
# ⚠️  Warning: Data directory path doesn't contain 'Option_Pricing': /Users/mathisvillaret/Documents (mac)/Le CODE/data
#    Expected path should contain: .../Option_Pricing/data/
#    Current working directory: /Users/mathisvillaret/Documents (mac)/Le CODE/Option_Pricing
#    ✅ Fixed path to: /Users/mathisvillaret/Documents (mac)/Le CODE/data
# 📁 Data will be saved to / loaded from: /Users/mathisvillaret/Documents (mac)/Le CODE/data
# 📂 Existing CSV found, loading instead of fetching from Yahoo Finance:
#    /Users/mathisvillaret/Documents (mac)/Le CODE/data/sp500_options_SPX_20251216_004012.csv
# 📊 Total rows in CSV: 16401
# ✅ Loaded all 16401 options from CSV (no date filtering)

# %%
df_test = spx_df2.copy()
df_test["expiry_date"] = pd.to_datetime(df_test["expiry_date"])
as_of = datetime.now()
df_test["T"] = (df_test["expiry_date"] - pd.Timestamp(as_of)).dt.total_seconds() / (365.25 * 24 * 3600)

# Filtrer T > 1
df_long = df_test[df_test["T"] > 1.0].copy()
print(f"Options avec T > 1 an: {len(df_long)}")

# Vérifier chaque filtre
print(f"\nAprès filtres de qualité:")
print(f"  - Avec bid/ask valides: {len(df_long[(df_long['bid_price'] > 0) & (df_long['ask_price'] > 0)])}")
print(f"  - Avec bid >= 0.01: {len(df_long[df_long['bid_price'] >= 0.01])}")
print(f"  - Avec liquidité (OI>=10 ou Vol>=1): {len(df_long[(df_long['open_interest'] >= 10) | (df_long['volume'] >= 1)])}")
print(f"  - Avec IV valide: {len(df_long[df_long['mark_iv'].notna()])}")
# Out:
# Options avec T > 1 an: 608
#
# Après filtres de qualité:
#   - Avec bid/ask valides: 537
#   - Avec bid >= 0.01: 538
#   - Avec liquidité (OI>=10 ou Vol>=1): 564
#   - Avec IV valide: 608

# %%
cfg = SurfaceConfig(
    min_T=1/365,  # Min 3-4 days Base 1 year =1, 1 month =1/12 etc.
    max_T=3   #
)
spx_surface_test = SPXIVSurface(spx_df2, cfg)
surface = SPXIVSurface(spx_df2, cfg=cfg)

fig = spx_surface_test.plot(
    title="SPX Implied Volatility Surface (OTM, forward-moneyness)",
    interpolate=True
)
fig.show()

# %%
from import_other_options import import_sp500_options_data

start_date = datetime.now().date()
end_date = (datetime.now() + timedelta(days=500)).date()

spx_df_test = import_sp500_options_data(
    start_date=start_date,
    end_date=end_date,
    ticker="^SPX",
    output_dir=data_dir
)

print("✓ spx_df loaded:", len(spx_df_test))
spx_df_test.head()
# Out:
# ⚠️  Warning: Data directory path doesn't contain 'Option_Pricing': /Users/mathisvillaret/Documents (mac)/Le CODE/data
#    Expected path should contain: .../Option_Pricing/data/
#    Current working directory: /Users/mathisvillaret/Documents (mac)/Le CODE/Option_Pricing
#    ✅ Fixed path to: /Users/mathisvillaret/Documents (mac)/Le CODE/data
# 📁 Data will be saved to / loaded from: /Users/mathisvillaret/Documents (mac)/Le CODE/data
# 📂 Existing CSV found, loading instead of fetching from Yahoo Finance:
#    /Users/mathisvillaret/Documents (mac)/Le CODE/data/sp500_options_SPX_20251216_004012.csv
# 📊 Total rows in CSV: 16401
# ✅ Loaded 11333 options after filtering by date range (2026-01-02 to 2027-05-17)
#    (5068 options filtered out)
# ✓ spx_df loaded: 11333
#       expiry_str expiry_date  strike type   mark_iv  mark_price  \
# 4750  2026-01-02  2026-01-02  2800.0    C  1.722536     4038.30
# 4751  2026-01-02  2026-01-02  2800.0    P  1.125004        0.10
# 4752  2026-01-02  2026-01-02  3000.0    P  1.041020        0.05
# 4753  2026-01-02  2026-01-02  3200.0    P  0.962891        0.05
# 4754  2026-01-02  2026-01-02  3400.0    C  1.415622     3439.30
#
#       underlying_price  open_interest  bid_price  ask_price  best_bid_price  \
# 4750       6816.509766            2.0     4011.4    4035.40          4011.4
# 4751       6816.509766           94.0        0.0       0.15             0.0
# 4752       6816.509766          162.0        0.0       0.15             0.0
# 4753       6816.509766          352.0        0.0       0.15             0.0
# 4754       6816.509766            1.0     3413.1    3437.10          3413.1
#
#       best_ask_price  volume           instrument_name       contractSymbol  \
# 4750         4035.40     NaN  ^SPX-2026-01-02-2800.0-C  SPXW260102C02800000
# 4751            0.15    33.0  ^SPX-2026-01-02-2800.0-P  SPXW260102P02800000
# 4752            0.15   229.0  ^SPX-2026-01-02-3000.0-P  SPXW260102P03000000
# 4753            0.15    13.0  ^SPX-2026-01-02-3200.0-P  SPXW260102P03200000
# 4754         3437.10     NaN  ^SPX-2026-01-02-3400.0-C  SPXW260102C03400000
#
#      underlying_ticker
# 4750              ^SPX
# 4751              ^SPX
# 4752              ^SPX
# 4753              ^SPX
# 4754              ^SPX

# %%
cfg = SurfaceConfig(
    min_T=0.5,  # Min 3-4 days Base 1 year =1, 1 month =1/12 etc.
    max_T=2.0   #
)
spx_surface_test = SPXIVSurface(spx_df_test, cfg)
surface = SPXIVSurface(spx_df_test, cfg=cfg)

fig = spx_surface_test.plot(
    title="SPX Implied Volatility Surface (OTM, forward-moneyness)",
    interpolate=False
)
fig.show()

# %%
# Vérifier quel CSV est chargé
import glob
csv_files = glob.glob(os.path.join(data_dir, "sp500_options_SPX_*.csv"))
print("CSV trouvés:")
for f in sorted(csv_files):
    print(f"  {f}")
    # Vérifier les dates dans chaque CSV
    df_check = pd.read_csv(f)
    df_check["expiry_date"] = pd.to_datetime(df_check["expiry_date"])
    print(f"    Expiry max: {df_check['expiry_date'].max()}")

# Supprimer les anciens CSV pour forcer le re-téléchargement
for f in csv_files:
    if "20251212" in f:  # Supprimer l'ancien CSV du 12 décembre
        os.remove(f)
        print(f"Supprimé: {f}")

# Puis re-importez
spx_df = import_sp500_options_data(
    start_date=datetime.now().date(),
    end_date=datetime(2027, 6, 17).date(),  # Date max que vous voulez
    ticker="^SPX",
    output_dir=data_dir,
    filter_by_date=False
)
# Out:
# CSV trouvés:
#   /Users/mathisvillaret/Documents (mac)/Le CODE/data/sp500_options_SPX_20251216_004012.csv
#     Expiry max: 2027-06-17 00:00:00
# ⚠️  Warning: Data directory path doesn't contain 'Option_Pricing': /Users/mathisvillaret/Documents (mac)/Le CODE/data
#    Expected path should contain: .../Option_Pricing/data/
#    Current working directory: /Users/mathisvillaret/Documents (mac)/Le CODE/Option_Pricing
#    ✅ Fixed path to: /Users/mathisvillaret/Documents (mac)/Le CODE/data
# 📁 Data will be saved to / loaded from: /Users/mathisvillaret/Documents (mac)/Le CODE/data
# 📂 Existing CSV found, loading instead of fetching from Yahoo Finance:
#    /Users/mathisvillaret/Documents (mac)/Le CODE/data/sp500_options_SPX_20251216_004012.csv
# 📊 Total rows in CSV: 16401
# ✅ Loaded all 16401 options from CSV (no date filtering)
